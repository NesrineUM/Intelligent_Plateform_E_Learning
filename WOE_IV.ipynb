# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import packages
import os
import pandas as pd
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/E-Learning/elearningdataset_level_activity.csv")
df=df.dropna(how='all', axis=1)

# %%
df.head()

# %%
df.info()

# %%
df['preferred level of interactivity type '].value_counts()

# %%
df['target'] = df['preferred level of interactivity type ']
df = df.drop('preferred level of interactivity type ',axis=1)

# %%
df.head()

# %% [markdown]
# # WOE and IV

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(df,df.target)

# %%
final_iv
# Out:
#                                              VAR_NAME  ...        IV
# 0                                                Age   ...  0.000073
# 1                                                Age   ...  0.000073
# 2                                                Sex   ...  0.000145
# 3                                                Sex   ...  0.000145
# 4                                    Program of study  ...  0.000089
# 5                                    Program of study  ...  0.000089
# 6                                             College  ...  0.000819
# 7                                             College  ...  0.000819
# 8                                         Level Study  ...  0.001753
# 9                                         Level Study  ...  0.001753
# 10                                        Level Study  ...  0.001753
# 11                                             Branch  ...  0.000025
# 12                                             Branch  ...  0.000025
# 13                                         Have a job  ...  0.000052
# 14                                         Have a job  ...  0.000052
# 15                       Attending method prefer more  ...  0.001613
# 16                       Attending method prefer more  ...  0.001613
# 17   experience in handling e-Learning platform tools  ...  0.001255
# 18   experience in handling e-Learning platform tools  ...  0.001255
# 19   total number of lectures prefer to attend daily   ...  0.001280
# 20   total number of lectures prefer to attend daily   ...  0.001280
# 21   total number of lectures prefer to attend daily   ...  0.001280
# 22    frequently contact instructor to ask inquiries   ...  0.001870
# 23    frequently contact instructor to ask inquiries   ...  0.001870
# 24  motivated using the interfaces of the e-Learni...  ...  0.000370
# 25  motivated using the interfaces of the e-Learni...  ...  0.000370
# 26  interested in revising the recorded lectures o...  ...  0.000567
# 27  interested in revising the recorded lectures o...  ...  0.000567
# 28                   learning resource preferred most  ...  0.001832
# 29                   learning resource preferred most  ...  0.001832
# 30       Type of assessment activity preferred most?   ...  0.001041
# 31       Type of assessment activity preferred most?   ...  0.001041
# 32  Preferred  semantic density (amount of content...  ...  0.000326
# 33  Preferred  semantic density (amount of content...  ...  0.000326
# 34  Preferred electronic device to access the cour...  ...  0.000095
# 35  Preferred electronic device to access the cour...  ...  0.000095
# 36  Preferred background color for your e-Learning...  ...  0.000001
# 37  Preferred background color for your e-Learning...  ...  0.000001
# 38  Preferred text color for your course text cont...  ...  0.000033
# 39  Preferred text color for your course text cont...  ...  0.000033
#
# [40 rows x 12 columns]

# %%
IV.sort_values('IV')
# Out:
#                                              VAR_NAME        IV
# 7   Preferred background color for your e-Learning...  0.000001
# 2                                              Branch  0.000025
# 9   Preferred text color for your course text cont...  0.000033
# 4                                          Have a job  0.000052
# 0                                                Age   0.000073
# 10                                   Program of study  0.000089
# 8   Preferred electronic device to access the cour...  0.000095
# 11                                               Sex   0.000145
# 6   Preferred  semantic density (amount of content...  0.000326
# 17  motivated using the interfaces of the e-Learni...  0.000370
# 15  interested in revising the recorded lectures o...  0.000567
# 3                                             College  0.000819
# 12       Type of assessment activity preferred most?   0.001041
# 13   experience in handling e-Learning platform tools  0.001255
# 18   total number of lectures prefer to attend daily   0.001280
# 1                        Attending method prefer more  0.001613
# 5                                         Level Study  0.001753
# 16                   learning resource preferred most  0.001832
# 14    frequently contact instructor to ask inquiries   0.001870

# %%
IV.to_csv('test.csv')

# %% [markdown]
# # Apply WOE values to your dataframe columns

# %% [markdown]
# The below code snippet can be used to apply the WOE values to your dataframe columns.

# %%
transform_vars_list = df.columns.difference(['target'])
transform_prefix = 'new_' # leave this value blank if you need replace the original column values

# %%
transform_vars_list
# Out:
# Index(['age', 'balance', 'campaign', 'contact', 'day', 'default', 'duration',
#        'education', 'housing', 'job', 'loan', 'marital', 'month', 'pdays',
#        'poutcome', 'previous'],
#       dtype='object')

# %%
for var in transform_vars_list:
    small_df = final_iv[final_iv['VAR_NAME'] == var]
    transform_dict = dict(zip(small_df.MAX_VALUE,small_df.WOE))
    replace_cmd = ''
    replace_cmd1 = ''
    for i in sorted(transform_dict.items()):
        replace_cmd = replace_cmd + str(i[1]) + str(' if x <= ') + str(i[0]) + ' else '
        replace_cmd1 = replace_cmd1 + str(i[1]) + str(' if x == "') + str(i[0]) + '" else '
    replace_cmd = replace_cmd + '0'
    replace_cmd1 = replace_cmd1 + '0'
    if replace_cmd != '0':
        try:
            df[transform_prefix + var] = df[var].apply(lambda x: eval(replace_cmd))
        except:
            df[transform_prefix + var] = df[var].apply(lambda x: eval(replace_cmd1))

# %%
df['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df['new_contact'].value_counts()
# Out:
#  0.252971    2896
# -0.992072    1324
#  0.273413     301
# Name: new_contact, dtype: int64

# %%
small_df = final_iv[final_iv['VAR_NAME'] == 'contact']

# %%
small_df
# Out:
#    VAR_NAME  MIN_VALUE  MAX_VALUE  COUNT  EVENT  EVENT_RATE  NONEVENT  \
# 31  contact   cellular   cellular   2896    416    0.143646      2480
# 32  contact  telephone  telephone    301     44    0.146179       257
# 33  contact    unknown    unknown   1324     61    0.046073      1263
#
#     NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT       WOE        IV
# 31        0.856354    0.798464         0.62000  0.252971  0.247762
# 32        0.853821    0.084453         0.06425  0.273413  0.247762
# 33        0.953927    0.117083         0.31575 -0.992072  0.247762
